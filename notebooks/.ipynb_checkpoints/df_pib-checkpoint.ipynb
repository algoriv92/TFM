# %% [markdown]
# <div>
# <img src="attachment:university-college-financial-studies-madrid-spain.png" align="left" width="150"/>
# </div>

# %% [markdown]
# # **Producto Interior Bruto**

# %% [markdown]
# ## *Librerías*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
from sktime.forecasting.arima import AutoARIMA
from statsmodels.graphics import tsaplots
from sktime.utils.plotting import plot_correlations
from statsmodels.tsa.seasonal import seasonal_decompose
from sktime.transformations.series.boxcox import LogTransformer
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.transformations.series.difference import Differencer
from sktime.utils.plotting import plot_series
from sktime.forecasting.ets import AutoETS
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Lectura del CSV y preparación de los datos*
# Se procede a leer el archivo CSV del PIB trimestral español:
#
# - Fuente: Instituto Nacional de Estadística (INE)

# %%
df_pib = pd.read_csv("pibtrimestral.csv", sep = ";", encoding='latin-1')
df_pib
# Out:
#                                           Tipo de dato  \
# 0    Datos no ajustados de estacionalidad y calendario
# 1    Datos no ajustados de estacionalidad y calendario
# 2    Datos no ajustados de estacionalidad y calendario
# 3    Datos no ajustados de estacionalidad y calendario
# 4    Datos no ajustados de estacionalidad y calendario
# ..                                                 ...
# 106  Datos no ajustados de estacionalidad y calendario
# 107  Datos no ajustados de estacionalidad y calendario
# 108  Datos no ajustados de estacionalidad y calendario
# 109  Datos no ajustados de estacionalidad y calendario
# 110                                                NaN
#
#                Agregados macroeconómicos: Nivel 1  \
# 0    Producto interior bruto a precios de mercado
# 1    Producto interior bruto a precios de mercado
# 2    Producto interior bruto a precios de mercado
# 3    Producto interior bruto a precios de mercado
# 4    Producto interior bruto a precios de mercado
# ..                                            ...
# 106  Producto interior bruto a precios de mercado
# 107  Producto interior bruto a precios de mercado
# 108  Producto interior bruto a precios de mercado
# 109  Producto interior bruto a precios de mercado
# 110                                           NaN
#
#      Agregados macroeconómicos: Nivel 2 Niveles y tasas Periodo    total
# 0                                   NaN       Dato base  1995T1  109.165
# 1                                   NaN       Dato base  1995T2  116.633
# 2                                   NaN       Dato base  1995T3  112.398
# 3                                   NaN       Dato base  1995T4  122.392
# 4                                   NaN       Dato base  1996T1  115.776
# ..                                  ...             ...     ...      ...
# 106                                 NaN       Dato base  2021T3  297.498
# 107                                 NaN       Dato base  2021T4  327.744
# 108                                 NaN       Dato base  2022T1  310.012
# 109                                 NaN       Dato base  2022T2  327.758
# 110                                 NaN             NaN     NaN      NaN
#
# [111 rows x 6 columns]

# %% [markdown]
# Hacemos una limpieza de columnas y filas para escoger solo el total del PIB desde enero del 2010 hasta el último registro trimestral:

# %%
df_pib = df_pib.iloc[60:109,-2:]
df_pib.head()
# Out:
#    Periodo    total
# 60  2010T1  257.598
# 61  2010T2  273.434
# 62  2010T3  261.706
# 63  2010T4  279.971
# 64  2011T1  258.719

# %%
df_pib['Periodo'] = df_pib['Periodo'].str.replace('T', 'Q')
df_pib['Periodo'] = pd.to_datetime(df_pib['Periodo'].str.replace(r'(Q\d) (\d+)', r'\2-\1'), errors= 'coerce')
df_pib.head()
# Out:
#       Periodo    total
# 60 2010-01-01  257.598
# 61 2010-04-01  273.434
# 62 2010-07-01  261.706
# 63 2010-10-01  279.971
# 64 2011-01-01  258.719

# %%
# convert to period
df_pib['Periodo'] = pd.to_datetime(df_pib['Periodo']).dt.to_period('M')
df_pib = df_pib.set_index('Periodo').resample('M').interpolate()

# %%
df_pib
# Out:
#               total
# Periodo
# 2010-01  257.598000
# 2010-02  262.876667
# 2010-03  268.155333
# 2010-04  273.434000
# 2010-05  269.524667
# ...             ...
# 2021-09  317.662000
# 2021-10  327.744000
# 2021-11  321.833333
# 2021-12  315.922667
# 2022-01  310.012000
#
# [145 rows x 1 columns]

# %% [markdown]
# ## *Graficación de la serie temporal y análisis*

# %%
# Ploteamos nuestra serie temporal:
sns.set(rc={'figure.figsize':(20, 10)})
fig = df_pib.total.plot(marker='.') 
fig.set_ylabel('Ingresos', fontsize = 30)
fig.axvline('2020-03-01', color = 'red', linewidth= 1.5)
fig.set_xlabel('Periodo', fontsize = 30);

# %%
def split_and_summarize(dataframe, column, size, fn):
    ranges = []
    values = []
    for i in range(0, len(dataframe), size):
        ranges.append(dataframe[i:i + size])
    for i in ranges:
        values.append(fn(i[column]))
    return(values)

# %%
mean = split_and_summarize(df_pib, 'total', 4, np.mean)
variance = split_and_summarize(df_pib, 'total', 4, np.var)

# %%
cols = ['mean', 'variance']
df = pd.DataFrame([mean, variance], index=cols)

sns.set(rc={'figure.figsize':(15, 7)})
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(mean, ',-')
ax1.set_ylabel('Mean')

ax2.plot(variance, ',-')
ax2.set_ylabel('Variance')

plt.show()

# %%
ax = plt.gca()
sm.graphics.tsa.month_plot(df_pib.total, ax=ax)
ax.set_title('Comportamiento Estacional');

# %%
df_pib['M'] = df_pib.index.month
sns.boxplot(data = df_pib, x = 'M', y='total', showmeans=True)
ax = plt.gca()
ax.set_ylabel('PIB', fontsize = 20)
ax.set_title('Comportamiento estacional', fontsize = 30);

# %%
desglose = seasonal_decompose(df_pib.total, 
                              model='additive',
                              extrapolate_trend='freq',
                              period=12);
desglose.plot();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ALEJAN~1.RIV\AppData\Local\Temp/ipykernel_24556/3211347155.py in <module>
#       3                               extrapolate_trend='freq',
#       4                               period=12);
# ----> 5 desglose.plot();
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in plot(self, observed, seasonal, trend, resid, weights)
#     325         for i, (ax, (series, def_name)) in enumerate(zip(axs, series)):
#     326             if def_name != "residual":
# --> 327                 ax.plot(series)
#     328             else:
#     329                 ax.plot(series, marker="o", linestyle="none")
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     494
#     495         if self.axes.xaxis is not None:
# --> 496             self.axes.xaxis.update_units(x)
#     497         if self.axes.yaxis is not None:
#     498             self.axes.yaxis.update_units(y)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1451
#    1452         if neednew:
# -> 1453             self._update_axisinfo()
#    1454         self.stale = True
#    1455         return True
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _update_axisinfo(self)
#    1487             self.isDefault_label = True
#    1488
# -> 1489         self.set_default_intervals()
#    1490
#    1491     def have_units(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in set_default_intervals(self)
#    2258                 if info.default_limits is not None:
#    2259                     valmin, valmax = info.default_limits
# -> 2260                     xmin = self.converter.convert(valmin, self.units, self)
#    2261                     xmax = self.converter.convert(valmax, self.units, self)
#    2262             if not dataMutated:
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in convert(values, units, axis)
#     229             values = [PeriodConverter._convert_1d(v, units, axis) for v in values]
#     230         else:
# --> 231             values = PeriodConverter._convert_1d(values, units, axis)
#     232         return values
#     233
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in _convert_1d(values, units, axis)
#     235     def _convert_1d(values, units, axis):
#     236         if not hasattr(axis, "freq"):
# --> 237             raise TypeError("Axis must have `freq` set to convert to Periods")
#     238         valid_types = (str, datetime, Period, pydt.date, pydt.time, np.datetime64)
#     239         if isinstance(values, valid_types) or is_integer(values) or is_float(values):
#
# TypeError: Axis must have `freq` set to convert to Periods
