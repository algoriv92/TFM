# %% [markdown]
# <div> <img src="attachment:university-college-financial-studies-madrid-spain.png" align="left" width="150"/>
# </div>

# %% [markdown]
# # **Hipotecas en España**

# %% [markdown]
# ## *Librerías*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
from sktime.forecasting.arima import AutoARIMA
from statsmodels.graphics import tsaplots
from sktime.utils.plotting import plot_correlations
from statsmodels.tsa.seasonal import seasonal_decompose
from sktime.transformations.series.boxcox import LogTransformer
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.transformations.series.difference import Differencer
from sktime.utils.plotting import plot_series
from sktime.forecasting.ets import AutoETS
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Lectura del CSV y preparación de los datos*
# Se procede a leer el archivo CSV del número de hipotecas del TOTAL DE FINCAS en España.
#
# - Fuente: https://datos.gob.es/es/catalogo/ea0010587-hipotecas-constituidas-sobre-el-total-de-fincas-por-naturaleza-de-la-finca-mensual-comunidades-autonomas-estadistica-de-hipotecas-identificador-api-138961

# %%
df_hipotecas = pd.read_csv("hipotecas.csv", sep = ";", on_bad_lines='skip')
df_hipotecas
# Out:
#       Comunidades Autonomas Naturaleza de la finca      Número e importe  \
# 0            Total Nacional           Total fincas   Número de hipotecas
# 1            Total Nacional           Total fincas   Número de hipotecas
# 2            Total Nacional           Total fincas   Número de hipotecas
# 3            Total Nacional           Total fincas   Número de hipotecas
# 4            Total Nacional           Total fincas   Número de hipotecas
# ...                     ...                    ...                   ...
# 55195          17 Rioja, La                  Otros  Importe de hipotecas
# 55196          17 Rioja, La                  Otros  Importe de hipotecas
# 55197          17 Rioja, La                  Otros  Importe de hipotecas
# 55198          17 Rioja, La                  Otros  Importe de hipotecas
# 55199          17 Rioja, La                  Otros  Importe de hipotecas
#
#        Periodo   Total
# 0      2022M02  49.147
# 1      2022M01  46.946
# 2      2021M12  43.702
# 3      2021M11  49.768
# 4      2021M10  49.053
# ...        ...     ...
# 55195  2003M05  25.726
# 55196  2003M04  14.410
# 55197  2003M03  14.926
# 55198  2003M02   8.950
# 55199  2003M01  15.285
#
# [55200 rows x 5 columns]

# %% [markdown]
# Observamos que el DataFrame que nos lee Jupyter Notebook tiene varios valores en las filas en cada variable, vamos a mirar qué contiene en las variables "Comunidades Autónomas" y "Naturaleza de la finca" por si nos interesa para algo en nuestro análisis:

# %%
df_hipotecas['Comunidades Autonomas'].unique()
# Out:
# array(['Total Nacional', '01 Andalucía', '02 Aragón',
#        '03 Asturias, Principado de', '04 Balears, Illes', '05 Canarias',
#        '06 Cantabria', '08 Castilla - La Mancha', '07 Castilla y León',
#        '09 Cataluña', '18 Ceuta', '10 Comunitat Valenciana',
#        '11 Extremadura', '12 Galicia', '13 Madrid, Comunidad de',
#        '19 Melilla', '14 Murcia, Región de',
#        '15 Navarra, Comunidad Foral de', '16 País Vasco', '17 Rioja, La'],
#       dtype=object)

# %%
df_hipotecas['Naturaleza de la finca'].unique()
# Out:
# array(['Total fincas', 'Total fincas rústicas', 'Total fincas urbanas',
#        'Viviendas', 'Solares', 'Otros'], dtype=object)

# %% [markdown]
# Del DataFrame, lo único que nos interesa son los datos a nivel nacional y el número total de fincas que engloba todos los tipos de fincas e inmuebles que han habido (hasta la fila 231 del CSV)

# %%
df_hipotecas = df_hipotecas.iloc[0:230, 0:5]
df_hipotecas
# Out:
#     Comunidades Autonomas Naturaleza de la finca     Número e importe  \
# 0          Total Nacional           Total fincas  Número de hipotecas
# 1          Total Nacional           Total fincas  Número de hipotecas
# 2          Total Nacional           Total fincas  Número de hipotecas
# 3          Total Nacional           Total fincas  Número de hipotecas
# 4          Total Nacional           Total fincas  Número de hipotecas
# ..                    ...                    ...                  ...
# 225        Total Nacional           Total fincas  Número de hipotecas
# 226        Total Nacional           Total fincas  Número de hipotecas
# 227        Total Nacional           Total fincas  Número de hipotecas
# 228        Total Nacional           Total fincas  Número de hipotecas
# 229        Total Nacional           Total fincas  Número de hipotecas
#
#      Periodo    Total
# 0    2022M02   49.147
# 1    2022M01   46.946
# 2    2021M12   43.702
# 3    2021M11   49.768
# 4    2021M10   49.053
# ..       ...      ...
# 225  2003M05  116.615
# 226  2003M04  104.744
# 227  2003M03  116.565
# 228  2003M02  119.166
# 229  2003M01  118.040
#
# [230 rows x 5 columns]

# %% [markdown]
# Comprobamos que solo tenemos los valores totales nacionales, total de fincas y solo hipotecas:

# %%
df_hipotecas['Comunidades Autonomas'].unique()
# Out:
# array(['Total Nacional'], dtype=object)

# %%
df_hipotecas['Naturaleza de la finca'].unique()
# Out:
# array(['Total fincas'], dtype=object)

# %%
df_hipotecas['Número e importe'].unique()
# Out:
# array(['Número de hipotecas'], dtype=object)

# %% [markdown]
# Una vez comprobadas que en las columnas solo están los datos que queremos, como ya no nos sirve para nada las variables de "Comunidades Autónomas, "Naturaleza de la finca" y "Número e importe", hacemos otro iloc para quitarlas y ya solamente nos centramos en trabajar con los datos del total de hipotecas:

# %%
df_hipotecas = df_hipotecas.iloc[:, 3:5]
df_hipotecas
# Out:
#      Periodo    Total
# 0    2022M02   49.147
# 1    2022M01   46.946
# 2    2021M12   43.702
# 3    2021M11   49.768
# 4    2021M10   49.053
# ..       ...      ...
# 225  2003M05  116.615
# 226  2003M04  104.744
# 227  2003M03  116.565
# 228  2003M02  119.166
# 229  2003M01  118.040
#
# [230 rows x 2 columns]

# %% [markdown]
# Cambiamos el formato de la fecha y cambiamos el formato del número quitando el punto separador de millares:

# %%
# Convertimos en formato fecha
df_hipotecas['Periodo'] = df_hipotecas['Periodo'].str.replace('M', '')
df_hipotecas['Periodo'] = pd.to_datetime(df_hipotecas['Periodo'], format='%Y%m')

# %%
df_hipotecas = df_hipotecas.set_index("Periodo")
df_hipotecas
# Out:
#               Total
# Periodo
# 2022-02-01   49.147
# 2022-01-01   46.946
# 2021-12-01   43.702
# 2021-11-01   49.768
# 2021-10-01   49.053
# ...             ...
# 2003-05-01  116.615
# 2003-04-01  104.744
# 2003-03-01  116.565
# 2003-02-01  119.166
# 2003-01-01  118.040
#
# [230 rows x 1 columns]

# %%
df_hipotecas['Total']=df_hipotecas['Total'].str.replace('.', '').astype(float)

# %% [markdown]
# ## *Graficación de la serie temporal*

# %%
sns.set(rc={'figure.figsize':(18, 6)})
fig = df_hipotecas.plot(marker='.') 
fig.set_ylabel('Nº hipotecas', fontsize = 30)
fig.axvline('2020-03-01', color = 'red', linewidth= 1.5)
fig.set_xlabel('Meses', fontsize = 30);

# %% [markdown]
# La gráfica distorsiona demasiado los datos más recientes, por lo que vamos a aplicar un zoom desde finales del 2013 en adelante:

# %%
df_hipotecas =  df_hipotecas.iloc[:100]

sns.set(rc={'figure.figsize':(18, 6)})
fig = df_hipotecas.plot(marker='.') 
fig.set_ylabel('Nº hipotecas', fontsize = 30)
fig.axvline('2020-03-01', color = 'red', linewidth= 1.5)
fig.set_xlabel('Meses', fontsize = 30);

# %% [markdown]
# La gráfica presenta una tendencia creciente con una caída en el momento COVID. Debido al confinamiento, no ha habido ventas de inmuebles y se puede reflejar en los meses siguientes a los de febrero del 2020. Sin embargo, a día de hoy la tendencia se está recuperando y está siendo creciente.

# %% [markdown]
# A continuación, analizaremos la estacionalidad mediante:
# - Cálculo de la media y de la varianza
# - Gráficas de comportamiento mensual
# - Desglose de la tendencia, de la estacionalidad y residuos

# %%
def split_and_summarize(dataframe, column, size, fn):
    ranges = []
    values = []
    for i in range(0, len(dataframe), size):
        ranges.append(dataframe[i:i + size])
    for i in ranges:
        values.append(fn(i[column]))
    return(values)

# %%
media = split_and_summarize(df_hipotecas, 'Total', 4, np.mean)

varianza = split_and_summarize(df_hipotecas, 'Total', 4, np.var)

# %%
cols = ['media', 'varianza']
df = pd.DataFrame([media, varianza], index=cols)

sns.set(rc={'figure.figsize':(15, 7)})
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(media, ',-')
ax1.set_ylabel('Media')

ax2.plot(varianza, ',-')
ax2.set_ylabel('Varianza')

plt.show()

# %% [markdown]
# A continuación vamos a analizar con más detalle la estacionalidad y su tendencia:
#
# <font color='red'>CORREGIR ESTO</font>

# %%
# Componente estacional mensual:
ax = plt.gca() 
sm.graphics.tsa.month_plot(df_hipotecas['Total'], ax = ax)
ax.set_title('Comportamiento mensual', fontsize = 30);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ALEJAN~1.RIV\AppData\Local\Temp/ipykernel_1588/1526888702.py in <module>
#       1 # Componente estacional mensual:
#       2 ax = plt.gca()
# ----> 3 sm.graphics.tsa.month_plot(df_hipotecas['Total'], ax = ax)
#       4 ax.set_title('Comportamiento mensual', fontsize = 30);
#
# ~\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in month_plot(x, dates, ylabel, ax)
#     460         from statsmodels.tools.data import _check_period_index
#     461
# --> 462         _check_period_index(x, freq="M")
#     463     else:
#     464         x = pd.Series(x, index=pd.PeriodIndex(dates, freq="M"))
#
# ~\anaconda3\lib\site-packages\statsmodels\tools\data.py in _check_period_index(x, freq)
#      16         inferred_freq = pd.infer_freq(x.index)
#      17     if not inferred_freq.startswith(freq):
# ---> 18         raise ValueError("Expected frequency {}. Got {}".format(inferred_freq,
#      19                                                                 freq))
#      20
#
# ValueError: Expected frequency -1MS. Got M

# %% [markdown]
# Pasamos a realizar un boxplot mensual para estudiar las distribuciones:

# %%
df_hipotecas['M'] = df_hipotecas.index.month
sns.boxplot(data = df_hipotecas, x = 'M', y='Total', showmeans=True)
ax = plt.gca()
ax.set_ylabel('Hipotecas', fontsize = 20)
ax.set_title('Comportamiento mensual', fontsize = 30);

# %% [markdown]
# Y, por último, el desglose de la estacionalidad, tendencia y residuos:
#
# # <font color = red> EL PERIODO SALE AL REVÉS, CORREGIRLO </font>

# %%
desglose = seasonal_decompose(df_hipotecas['Total'], 
                                   model='additive', 
                                   period=12);
desglose.plot();

# %% [markdown]
# Analizando las gráficas, observamos:
# - Lo comentado anteriormente en cuanto a tendencia. El COVID afecta ligeramente a la venta de inmuebles pero a los meses se vuelve a recuperar la tendencia.
# - Se aprecia una estacionalidad en la que hay más ventas de inmuebles en los meses de enero, mayo y septiembre y menos ventas en los meses de abril, agosto y diciembre.
# - Que no es una serie con estacionariedad debido a la irregularidad que hay en la media y en la varianza.

# %% [markdown]
# ## *Modelo de suavizado exponencial (ETS)*
# A continuación, se realiza una segmentación en la estimación y en la parte de predicción (Training-Testing), prediciéndolo en un año.
