# %% [markdown]
# <div>
# <img src="attachment:university-college-financial-studies-madrid-spain.png"  align="left" width="150"/>
# </div>

# %% [markdown]
# # **Desempleo en España (intervenido)**
#
# En este notebook se mostrará la serie temporal de la **tasa de paro INTERVENIDO en España** y observaremos cómo afectó ésta frente al COVID-19. Haremos más resumido los dos primeros pasos ya que lo hemos realizado previamente en el DataFrame sin manipular la época COVID-19

# %% [markdown]
# Estructura del notebook:
#
#     1) Librerías utilizadas
#     2) Lectura, preprocesado e intervención del momento COVID-19
#     3) EDA (Análisis Exploratorio de Datos)
#     4) Elección del modelo predictivo
#         4.1) Modelo de suavizado exponencial (ETS)
#         4.2) Modelo autorregresivo integrado de media móvil (ARIMA)
#         4.3) Modelo FB Prophet
#         4.4) Comparativa errores y elección del mejor modelo
#     5) Predicción hasta finales de año

# %% [markdown]
# ## *1) Librerías utilizadas*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
from prophet import Prophet
from sktime.forecasting.arima import AutoARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics import tsaplots
from sktime.utils.plotting import plot_correlations
from statsmodels.tsa.seasonal import seasonal_decompose
from sktime.transformations.series.boxcox import LogTransformer
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sktime.performance_metrics.forecasting import MeanSquaredError
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.transformations.series.difference import Differencer
from sktime.utils.plotting import plot_series
from sktime.forecasting.ets import AutoETS
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *2) Lectura, preprocesado e intervención del momento COVID-19*
#
# - Fuente: https://www.sepe.es/HomeSepe/que-es-el-sepe/estadisticas/datos-avance/paro.html

# %%
df_paro=pd.read_excel("evolparoseries2.xls",index_col=0)
df_paro.tail()
# Out:
#         mes    total  agricultura  industria  construccion  servicios  \
# NaN  202203  3108763       156354     254532        249107    2192580
# NaN  202204  3022503       146810     250192        242135    2127158
# NaN  202205  2922991       138117     242224        232127    2062928
# NaN  202206  2880582       146980     235076        227146    2021911
# NaN  202207  2883812       147805     233167        228122    2033148
#
#      sin_empleo_ant
# NaN          256190
# NaN          256208
# NaN          247595
# NaN          249469
# NaN          241570

# %%
df_paro.mes=pd.to_datetime(df_paro.mes,format='%Y%m')

df_paro=df_paro.set_index("mes")
df_paro=df_paro.iloc[:,0:1]
df_paro
# Out:
#               total
# mes
# 2013-01-01  4980778
# 2013-02-01  5040222
# 2013-03-01  5035243
# 2013-04-01  4989193
# 2013-05-01  4890928
# ...             ...
# 2022-03-01  3108763
# 2022-04-01  3022503
# 2022-05-01  2922991
# 2022-06-01  2880582
# 2022-07-01  2883812
#
# [115 rows x 1 columns]

# %% [markdown]
# Vamos a realizar una comparación de la media antes del momento COVID-19 y la media de después:

# %%
print('Media de desempleados en España antes del COVID-19: ',
      df_paro['total'].loc["2013-01":'2020-03'].mean())
print('-----------------------------')
print('Media de desempleados en España después del COVID-19: ',
      df_paro['total'].loc['2020-03':].mean())
# Out:
# Media de desempleados en España antes del COVID-19:  3902785.3908045976
# -----------------------------
# Media de desempleados en España después del COVID-19:  3512216.7586206896

# %% [markdown]
# Se observa que la media es alterada y nos ha perjudicado en la predicción que se ha hecho en el df_paro. Vamos a hacer de nuevo una representación gráfica del desempleo en el momento COVID-19 y vamos a ver qué meses son los que más alteran la predicción:

# %%
sns.set(rc={'figure.figsize':(20,10)})
fig=df_paro.total['2019':].plot(marker='.',color ='black',linewidth= 2)
fig.set_title('Evolución temporal del desempleo español',fontsize=30)
fig.set_ylabel('Total paro (mill. personas)',fontsize=20)
fig.axvline('2020-03-01',color='red',linewidth=1.5)
fig.axvline('2021-07-01', color='red', linewidth=1.5)
fig.set_xlabel('Periodo',fontsize=20);

# %% [markdown]
# Vemos que desde marzo del 2020 hasta julio del 2021 son los meses que más datos de desempleo hay por el efecto COVID-19, esto son 17 meses (incluyendo los meses de marzo y julio). Vamos a quedarnos con los datos hasta febrero del 2020, justo antes del inicio de la pandemia en nuestro país, y vamos a hacer un entrenamiento-test con autoETS para rellenar los datos hasta julio 2021 inclusive.
#
# **¿Por qué con AutoETS?** Porque se ha comprobado en el análisis anterior que era más preciso que el autoARIMA.

# %%
# Nos quedamos de momento con los datos hasta febrero de 2021:
df_paro2 = df_paro.loc['2013-02':'2020-02']
# Hacemos la predicción sobre esta time series:
df_paro2.plot();

# %%
#y_train, y_test
y_train, y_test = temporal_train_test_split(
    y=df_paro2['total'].astype('float64').to_period('M'),test_size = 17) # 17 meses (mar2020 - jul2021)
plot_series(y_train, y_test, labels=["y_train","y_test"])
print('Cantidad de períodos en Train:', y_train.shape[0])
print('Cantidad de períodos en Test:', y_test.shape[0])
plt.show()
# Out:
# Cantidad de períodos en Train: 68
# Cantidad de períodos en Test: 17

# %% [markdown]
# Aplicamos el modelo AutoETS para que testee el modelo entrenado.

# %%
fh = np.arange(1, y_test.shape[0]+1)
paro_auto_ets=AutoETS(auto=True,sp=12,n_jobs=1)

# %%
paro_auto_ets.fit(y_train)
# Out:
# AutoETS(auto=True, n_jobs=1, sp=12)

# %%
paro_pred = paro_auto_ets.predict(fh)
paro_pred.round()
# Out:
# 2018-10    3259954.0
# 2018-11    3262177.0
# 2018-12    3206189.0
# 2019-01    3266958.0
# 2019-02    3265570.0
# 2019-03    3234145.0
# 2019-04    3159336.0
# 2019-05    3077255.0
# 2019-06    2994317.0
# 2019-07    2956832.0
# 2019-08    2977822.0
# 2019-09    2997412.0
# 2019-10    3050057.0
# 2019-11    3051005.0
# 2019-12    2997515.0
# 2020-01    3053169.0
# 2020-02    3050701.0
# Freq: M, dtype: float64

# %%
plot_series(y_train, paro_pred, y_test,labels= ["Paro", 'Paro PRED', 'Paro REAL'],)
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='total'>)

# %% [markdown]
# El modelo se comporta bien y da una precisión bastante buena, por lo que aplicaremos un horizonte nuevo de predicción y los datos que nos prediga hasta julio del 2021 serán los datos con los que vayamos a trabajar para testear los modelos y hacer una posterior predicción hasta finales del 2022.

# %%
paro_ficticio = df_paro.loc['2016-02': '2020-02']
fh=np.arange(1, 18) # hasta julio 2021 son 17 meses (marzo 2020 - julio 2021)
df_auto = AutoETS(auto= True, 
                  sp =12, #mensual
                  n_jobs=1)
y = paro_ficticio.total.astype('float64').to_period('M')
df_auto.fit(y)
print(df_auto.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  total   No. Observations:                   49
# Model:                       ETS(MNM)   Log Likelihood                -595.486
# Date:                Tue, 23 Aug 2022   AIC                           1222.973
# Time:                        10:58:07   BIC                           1253.242
# Sample:                    02-29-2016   HQIC                          1234.457
#                          - 02-29-2020   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.171      5.863      0.000       0.666       1.334
# smoothing_seasonal   2.501e-05      0.254   9.85e-05      1.000      -0.498       0.498
# initial_level        3.843e+06   2.81e-08   1.37e+14      0.000    3.84e+06    3.84e+06
# initial_seasonal.0      0.9963      0.027     37.378      0.000       0.944       1.049
# initial_seasonal.1      0.9697      0.028     34.770      0.000       0.915       1.024
# initial_seasonal.2      0.9812      0.027     36.411      0.000       0.928       1.034
# initial_seasonal.3      0.9727      0.028     35.000      0.000       0.918       1.027
# initial_seasonal.4      0.9494      0.027     34.905      0.000       0.896       1.003
# initial_seasonal.5      0.9386      0.027     35.393      0.000       0.887       0.991
# initial_seasonal.6      0.9221      0.028     32.527      0.000       0.867       0.978
# initial_seasonal.7      0.9267      0.028     33.027      0.000       0.872       0.982
# initial_seasonal.8      0.9477      0.027     35.276      0.000       0.895       1.000
# initial_seasonal.9      0.9703      0.025     38.256      0.000       0.921       1.020
# initial_seasonal.10     0.9923      0.025     39.589      0.000       0.943       1.041
# initial_seasonal.11     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                        1.83   Jarque-Bera (JB):              2504.64
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.04   Skew:                             5.52
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 5.33e+18. Standard errors may be unstable.

# %%
#step 5: querying predictions
paro_pred = df_auto.predict(fh=list(fh))
paro_pred.round()
# Out:
# 2020-03    3221036.0
# 2020-04    3149557.0
# 2020-05    3076371.0
# 2020-06    3008092.0
# 2020-07    2993202.0
# 2020-08    3046869.0
# 2020-09    3081875.0
# 2020-10    3157268.0
# 2020-11    3185016.0
# 2020-12    3147761.0
# 2021-01    3234131.0
# 2021-02    3246048.0
# 2021-03    3221036.0
# 2021-04    3149557.0
# 2021-05    3076371.0
# 2021-06    3008092.0
# 2021-07    2993202.0
# Freq: M, dtype: float64

# %% [markdown]
# Ya tenemos los datos predichos hasta junio-2021, vamos a suprimir los datos del desempleo alterados por la etapa COVID-19 y vamos a usar los datos predecidos por este modelo.

# %%
df_paro_new = df_paro
df_paro_new.loc['2020-03-01':'2021-07-01','total'] = ['3221036','3149557','3076371','3008092',
                                                     '2993202','3046869','3081875','3157268',
                                                     '3185016','3147761','3234131','3246048',
                                                     '3221036','3149557','3076371','3008092',
                                                     '2993202']

# %%
df_paro_new.tail()
# Out:
#               total
# mes
# 2022-03-01  3108763
# 2022-04-01  3022503
# 2022-05-01  2922991
# 2022-06-01  2880582
# 2022-07-01  2883812

# %%
# hay que pasar los datos de tipo objeto a tipo numérico (float)
df_paro_new = pd.to_numeric(df_paro_new.total)
df_paro_new.dtypes
# Out:
# dtype('int64')

# %%
sns.set(rc={'figure.figsize':(20,10)})
fig=df_paro_new.plot(marker='.',color ='black',linewidth= 2)
fig.set_title('Evolución desempleo intervenido',fontsize=30)
fig.set_ylabel('Total paro (mill. personas)',fontsize=20)
fig.axvline('2020-03-01',color='red',linewidth=1.5)
fig.axvline('2021-07-01', color='red', linewidth=1.5)
fig.set_xlabel('Periodo',fontsize=20);

# %% [markdown]
# Ahora sí que guarda una tendencia y una estacionalidad similar. Vamos a hacer un breve EDA y luego procedemos ahora a predecir la serie temporal con los modelos.

# %% [markdown]
# ## *3) EDA*
#
# ### 3.1) Test de Dickey-Fuller aumentada
#
# Esta prueba nos proporciona una verificación rápida y evidente de si la serie es estacionaria o no.
#
# **La hipótesis nula (H0)** de la prueba es que la serie temporal se puede representar mediante una raíz unitaria, que no es estacionaria, es decir, que tiene alguna estructura dependiente del tiempo.
#
# **La hipótesis alternativa (H1)**, que rechaza la hipótesis nula, indica que la serie temporal es estacionaria.
#
# Interpretamos este resultado utilizando el p-value. Un valor p por debajo del umbral de significancia (0.05) significa que la hipótesis nula se rechaza.

# %%
def test_stationarity(timeseries):
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

test_stationarity(df_paro_new)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.756246
# p-value                          0.064801
# #Lags Used                      12.000000
# Number of Observations Used    102.000000
# Critical Value (1%)             -3.496149
# Critical Value (5%)             -2.890321
# Critical Value (10%)            -2.582122
# dtype: float64

# %% [markdown]
# <u>La serie temporal sigue sin ser estacionaria</u>, debido a que el p-value del test Dickey-Fuller (0.06) es mayor que 0.05, y eso indica que se acepta la hipótesis nula (H0).
#
# Sin embargo, vemos que nuestro test estadístico (-2.75) es menor que el umbrales de significancia del 10% (-2.58), lo que puede decirse que la serie puede poseer alguna estructura que no sea dependiente del tiempo.

# %% [markdown]
# ### 3.2) Comportamiento mensual

# %%
ax=plt.gca() 
sm.graphics.tsa.month_plot(df_paro_new,ax=ax)
ax.set_title('Comportamiento mensual',fontsize=30);

# %% [markdown]
# Sigue cumpliendo con la estacionalidad del desempleo real aunque algo más suavizado.

# %% [markdown]
# ### 3.4.) Descomposición

# %%
desglose=seasonal_decompose(df_paro_new, 
                                   model='additive', 
                                   period=12);
desglose.plot();

# %% [markdown]
# Analizando las gráficas una vez intervenida la serie, observamos:
#
# - Que existe una **tendencia decreciente en todo momento**.
# - Que la serie **no es estacionaria**, aunque no es consistente del todo esa negación.
# - Hay **componente estacional**.

# %% [markdown]
# ## *4) Estimación mediante modelos*

# %% [markdown]
# ### 4.1) Modelo de Suavizado Exponencial (ETS)

# %%
#Train-test
y_train,y_test_ets=temporal_train_test_split(
    y=df_paro_new.astype('float64').to_period('M').sort_index(),test_size=29
)
# Grafico para representar la separación de los datos
plot_series(y_train, y_test_ets, labels=["y_train","y_test"])
print('Cantidad de períodos en Train:', y_train.shape[0])
print('Cantidad de períodos en Test:', y_test.shape[0])
plt.show()
# Out:
# Cantidad de períodos en Train: 86
# Cantidad de períodos en Test: 17

# %%
y_test_ets
# Out:
# 2020-03    3221036.0
# 2020-04    3149557.0
# 2020-05    3076371.0
# 2020-06    3008092.0
# 2020-07    2993202.0
# 2020-08    3046869.0
# 2020-09    3081875.0
# 2020-10    3157268.0
# 2020-11    3185016.0
# 2020-12    3147761.0
# 2021-01    3234131.0
# 2021-02    3246048.0
# 2021-03    3221036.0
# 2021-04    3149557.0
# 2021-05    3076371.0
# 2021-06    3008092.0
# 2021-07    2993202.0
# 2021-08    3333915.0
# 2021-09    3257802.0
# 2021-10    3257068.0
# 2021-11    3182687.0
# 2021-12    3105905.0
# 2022-01    3123078.0
# 2022-02    3111684.0
# 2022-03    3108763.0
# 2022-04    3022503.0
# 2022-05    2922991.0
# 2022-06    2880582.0
# 2022-07    2883812.0
# Freq: M, Name: total, dtype: float64

# %%
# Especifico la cantidad de períodos a estimar para obtener las observaciones predichas en test.
fh = np.arange(1, y_test_ets.shape[0]+1)

# Selecciono el modelo y sus parámetros de predicción, al igual que los recursos a utilizar para entrenar
paronew_auto_ets = AutoETS(auto=True, sp=12, n_jobs=-1)
paronew_auto_ets.fit(y_train)
# Out:
# AutoETS(auto=True, n_jobs=-1, sp=12)

# %%
#step 5: querying predictions
paronew_pred = paronew_auto_ets.predict(fh=list(fh))
(paronew_pred.round()).tail()
# Out:
# 2022-03    3138814.0
# 2022-04    3075082.0
# 2022-05    3005860.0
# 2022-06    2938286.0
# 2022-07    2916881.0
# Freq: M, dtype: float64

# %%
# optional: plotting predictions and past data
plot_series(y_train, paronew_pred, y_test_ets, labels=["Paro intervenido", "Paro int PRED", "Paro int REAL"])
plt.show()

# %%
mse = MeanSquaredError(square_root=True)
mse_ets = mse(y_test_ets, paronew_pred)
print('El modelo ETS genera un RMSE de:', round(mse_ets,2))
# Out:
# El modelo ETS genera un RMSE de: 89678.58

# %%
mape = MeanAbsolutePercentageError(symmetric=False)
mape_ets = mape(y_test_ets, paronew_pred)
print('El modelo ETS genera un MAPE de: {}%'.format(round(mape_ets*100,2)))
# Out:
# El modelo ETS genera un MAPE de: 1.72%

# %% [markdown]
# El modelo tiene un error muy pequeño y predice extremadamente bien.

# %% [markdown]
# ### 4.2) Modelo ARIMA

# %% [markdown]
# Al tratarse de una serie no estacionaria, transformamos la serie para tener un correcto tratamiento de la misma y de esta manera, obtener las mejores predicciones posibles con el método de estimacion ARIMA.
#
# Es necesario lograr que la serie sea estacionaria en varianza, luego el algoritmo es capaz de interpretar datos no estacionarios en media. Para ello, **aplicaremos logaritmo** y luego lo ploteamos para evidenciar si se ha logrado el objetivo.

# %%
transformer = LogTransformer()
log_df_paronew= transformer.fit_transform(df_paro_new)
log_df_paronew.tail()
# Out:
# mes
# 2022-03-01    14.949735
# 2022-04-01    14.921596
# 2022-05-01    14.888118
# 2022-06-01    14.873503
# 2022-07-01    14.874624
# dtype: float64

# %%
sns.set(rc={'figure.figsize':(20, 10)})
fig = log_df_paronew.plot(marker='.', color = 'black', linewidth= 2) 
fig.set_title('Desempleo intervenido', fontsize = 30) 
fig.set_ylabel('LOG Desempleo intervenido', fontsize = 30)
fig.set_xlabel('Periodo', fontsize = 30);

# %% [markdown]
# Separamos el train y el test a la serie transformada con logs:

# %%
y_log_train,y_log_test=temporal_train_test_split(
    y=log_df_paronew.astype('float64').to_period('M').sort_index(),test_size=29)

plot_series(y_log_train, y_log_test, labels=["y_log_train", "y_log_test"])
print(y_log_train.shape[0], y_log_test.shape[0])
plt.show()
# Out:
# 86 29

# %% [markdown]
# Generamos el modelo y se entrena con los datos del train:

# %%
fh = np.arange(1, y_log_test.shape[0]+1)
paronew_auto_arima=AutoARIMA(sp=12,suppress_warnings=True)

# %%
paronew_auto_arima.fit(y_log_train)
paronew_auto_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   86
# Model:             SARIMAX(0, 2, 1)x(1, 1, [], 12)   Log Likelihood                 270.913
# Date:                             Tue, 23 Aug 2022   AIC                           -533.826
# Time:                                     10:58:28   BIC                           -524.720
# Sample:                                          0   HQIC                          -530.201
#                                               - 86
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0002   8.67e-05      1.853      0.064   -9.25e-06       0.000
# ma.L1         -0.9071      0.128     -7.105      0.000      -1.157      -0.657
# ar.S.L12      -0.4579      0.128     -3.566      0.000      -0.710      -0.206
# sigma2      2.947e-05   6.18e-06      4.768      0.000    1.74e-05    4.16e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 0.95
# Prob(Q):                              0.70   Prob(JB):                         0.62
# Heteroskedasticity (H):               0.54   Skew:                             0.26
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
paronew_log_pred = paronew_auto_arima.predict(fh)
print(np.exp(paronew_log_pred))
# Out:
# 2020-03    3.224740e+06
# 2020-04    3.155616e+06
# 2020-05    3.091448e+06
# 2020-06    3.035278e+06
# 2020-07    3.039250e+06
# 2020-08    3.109034e+06
# 2020-09    3.145708e+06
# 2020-10    3.244354e+06
# 2020-11    3.276614e+06
# 2020-12    3.256217e+06
# 2021-01    3.368878e+06
# 2021-02    3.390167e+06
# 2021-03    3.386722e+06
# 2021-04    3.328505e+06
# 2021-05    3.276183e+06
# 2021-06    3.237946e+06
# 2021-07    3.263988e+06
# 2021-08    3.358715e+06
# 2021-09    3.415272e+06
# 2021-10    3.552893e+06
# 2021-11    3.613456e+06
# 2021-12    3.614860e+06
# 2022-01    3.763252e+06
# 2022-02    3.806351e+06
# 2022-03    3.827981e+06
# 2022-04    3.790167e+06
# 2022-05    3.758306e+06
# 2022-06    3.739392e+06
# 2022-07    3.795212e+06
# Freq: M, dtype: float64

# %%
# representamos la serie predictiva
plot_series(np.exp(y_log_train), np.exp(paronew_log_pred), np.exp(y_log_test),
            labels=["Paro int", "Paro int PRED", "Paro int REAL"])
plt.show()

# %%
mse = MeanSquaredError(square_root=True)
mse_log = mse(np.exp(y_log_test), np.exp(paronew_log_pred))
print('El modelo ARIMA genera un RMSE de:', round(mse_log,2))
# Out:
# El modelo ARIMA genera un RMSE de: 420416.2

# %%
mape = MeanAbsolutePercentageError(symmetric=False)
mape_log = mape(np.exp(y_log_test), np.exp(paronew_log_pred))
print('El modelo ARIMA genera un MAPE de: {}%'.format(round(mape_log*100,2)))
# Out:
# El modelo ARIMA genera un MAPE de: 9.83%

# %% [markdown]
# ### Comparativa gráfica entre los modelos ETS y ARIMA

# %%
plot_series(np.exp(y_log_train["2013":]),np.exp(paronew_log_pred),np.exp(y_log_test),paronew_pred,
            labels=['Paro int','Paro int ARIMA','Paro int REAL','Paro int ETS'])
plt.show()

# %% [markdown]
# Se aprecia bastante bien que el modelo de Suavizado Exponencial se ajusta más a los datos reales. Seguiremos probando ahora con otro modelo.

# %% [markdown]
# ### 4.3) Prophet

# %% [markdown]
# FB Prophet es un modelo muy extendido para la predicción de series temporales desarrollado por Facebook. El objetivo de este paquete es dar a los usuarios una herramienta potente y de fácil uso para predecir resultados de distintas series temporales. Este modelo alcanza sus mejores resultados con series estacionarias o series con una tendencia y estacionalidad marcadas, como es el caso del turismo en España. Suele ser peor cuando aumenta la aleatoria de la muestra.

# %% [markdown]
# Dentro de nuestro DataFrame cambiamos el nombre de la columna temporal *'Periodo'* y la de la variable objetivo *'Total'* por *'ds'* e *'y'*, y también quitamos el Periodo como índice, pues todos estos cambios son necesarios para que el modelo funcione bien.

# %%
prophet_train = df_paro_new.reset_index() #cambiamos de índice
prophet_train.columns = ['ds', 'y'] #renombramos las columnas

# %%
prophet_y_train = y_train.copy()
prophet_y_train = prophet_y_train.rename_axis('index').reset_index()
prophet_y_train.columns = ['ds', 'y']
prophet_y_train['ds'] = prophet_y_train['ds'].dt.to_timestamp(freq = 'M')
len(prophet_y_train)
# Out:
# 86

# %%
prophet_y_test = y_test.copy()
prophet_y_test = prophet_y_test.rename_axis('index').reset_index()
prophet_y_test.columns = ['ds', 'y']
prophet_y_test['ds'] = prophet_y_test['ds'].dt.to_timestamp(freq = 'M')
len(prophet_y_test)
# Out:
# 17

# %%
prophet_y_train.tail()
# Out:
#            ds          y
# 81 2019-10-31  3177659.0
# 82 2019-11-30  3198184.0
# 83 2019-12-31  3163605.0
# 84 2020-01-31  3253853.0
# 85 2020-02-29  3246047.0

# %%
prophet_y_test.head()
# Out:
#           ds          y
# 0 2018-10-31  3254703.0
# 1 2018-11-30  3252867.0
# 2 2018-12-31  3202297.0
# 3 2019-01-31  3285761.0
# 4 2019-02-28  3289040.0

# %%
m = Prophet()
m.fit(prophet_y_train)
# Out:
# 10:58:29 - cmdstanpy - INFO - Chain [1] start processing
# 10:58:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
m_pred = m.make_future_dataframe(periods=len(prophet_y_test), freq='M')
prophet_forecast = m.predict(m_pred)

# %%
plt.plot(list(prophet_y_test['y']), '.-')
plt.plot(list(prophet_forecast.loc[86:, 'yhat']), '.-', label='Predicition')
plt.show()

# %%
# Forecast Accuracy
# MAPE
# mape_prophet = mean_absolute_percentage_error(prophet_y_test['y'], prophet_forecast.loc[47:, 'yhat'])
# mape_prophet

mape = MeanAbsolutePercentageError(symmetric=False)
mape_prophet = mape(prophet_y_test['y'], prophet_forecast.loc[86:, 'yhat'])
print('El modelo Prophet genera un MAPE de: {}%'.format(round(mape_prophet*100,2)))
# Out:
# El modelo Prophet genera un MAPE de: 5.46%

# %%
# Forecast Accuracy
#Mean Squared Error
mse = MeanSquaredError(square_root=True)
mse_prophet = mse(prophet_y_test['y'],prophet_forecast.loc[86:, 'yhat'])
print('El modelo Prophet genera un RMSE de:', round(mse_prophet,2))
# Out:
# El modelo Prophet genera un RMSE de: 222163.24

# %%
prophet_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].round().tail()
# Out:
#             ds       yhat  yhat_lower  yhat_upper
# 98  2021-03-31  3119725.0   3069674.0   3170908.0
# 99  2021-04-30  3046280.0   2991402.0   3103228.0
# 100 2021-05-31  2954794.0   2897240.0   3017858.0
# 101 2021-06-30  2859457.0   2792276.0   2930488.0
# 102 2021-07-31  2828648.0   2755087.0   2902192.0

# %% [markdown]
# ### 4.4) Comparativa errores y elección del mejor modelo

# %% [markdown]
# Ahora comparamos entre las métricas de error que tenemos:
# 1) RMSE (Error dependiente de la escala)

# %%
print('El modelo ETS genera un RMSE de:', round(mse_ets,2))
print('El modelo ARIMA genera un RMSE de:', round(mse_log,2))
print('El modelo Prophet genera un RMSE de:', round(mse_prophet,2))
# Out:
# El modelo ETS genera un RMSE de: 89678.58
# El modelo ARIMA genera un RMSE de: 420416.2
# El modelo Prophet genera un RMSE de: 222163.24

# %% [markdown]
# 2) MAPE (Error porcentual)

# %%
print('El modelo ETS genera un MAPE de: {}%'.format(round(mape_ets*100,2)))
print('El modelo ARIMA genera un MAPE de {}%'.format(round(mape_log*100,2)))
print('El modelo Prophet genera un MAPE de {}%'.format(round(mape_prophet*100,2)))
# Out:
# El modelo ETS genera un MAPE de: 1.72%
# El modelo ARIMA genera un MAPE de 9.83%
# El modelo Prophet genera un MAPE de 5.46%

# %% [markdown]
# Confirmamos que **el mejor modelo para la predicción de esta serie temporal es la ETS**, ya que es el que mejor se ajusta a los datos reales y es el que menor error da.

# %% [markdown]
# ## *5) Predicción hasta finales de año*

# %% [markdown]
# A continuación realizamos la predicción de la serie temporal del desempleo intervenido hasta finales de año, es decir, hasta diciembre del 2022.

# %%
# Especifico la cantidad de períodos a estimar para obtener las observaciones predichas en test.
fh = np.arange(1, 6)

# Selecciono el modelo y sus parámetros de predicción, al igual que los recursos a utilizar para entrenar
autoets_predict = AutoETS(auto=True, sp=12, n_jobs=-1)
y = df_paro_new.astype('float64').to_period('M')
autoets_predict.fit(y)
# Out:
# AutoETS(auto=True, n_jobs=-1, sp=12)

# %%
print(autoets_predict.summary())
# Out:
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  total   No. Observations:                  115
# Model:                       ETS(MAM)   Log Likelihood               -1387.176
# Date:                Tue, 23 Aug 2022   AIC                           2810.352
# Time:                        11:07:32   BIC                           2859.761
# Sample:                    01-31-2013   HQIC                          2830.407
#                          - 07-31-2022   Scale                            0.000
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.093     10.725      0.000       0.817       1.183
# smoothing_trend         0.0551      0.035      1.579      0.114      -0.013       0.124
# smoothing_seasonal   2.923e-05        nan        nan        nan         nan         nan
# initial_level        4.869e+06    139.568   3.49e+04      0.000    4.87e+06    4.87e+06
# initial_trend       -2.344e+04   1.85e+04     -1.267      0.205   -5.97e+04    1.28e+04
# initial_seasonal.0      0.9766      0.012     83.329      0.000       0.954       1.000
# initial_seasonal.1      0.9894      0.012     80.390      0.000       0.965       1.014
# initial_seasonal.2      0.9863      0.013     78.353      0.000       0.962       1.011
# initial_seasonal.3      0.9653      0.013     77.069      0.000       0.941       0.990
# initial_seasonal.4      0.9579      0.012     77.664      0.000       0.934       0.982
# initial_seasonal.5      0.9335      0.012     78.742      0.000       0.910       0.957
# initial_seasonal.6      0.9380      0.012     76.675      0.000       0.914       0.962
# initial_seasonal.7      0.9576      0.012     77.225      0.000       0.933       0.982
# initial_seasonal.8      0.9796      0.012     78.634      0.000       0.955       1.004
# initial_seasonal.9      0.9998      0.012     80.682      0.000       0.975       1.024
# initial_seasonal.10     1.0043      0.012     83.485      0.000       0.981       1.028
# initial_seasonal.11     1.0000      0.011     87.999      0.000       0.978       1.022
# ===================================================================================
# Ljung-Box (Q):                        5.80   Jarque-Bera (JB):              3659.19
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.04   Skew:                             3.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                        29.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 8.88e+19. Standard errors may be unstable.

# %%
# Predicción del desempleo para los próximos 6 meses:
paronew_pred = autoets_predict.predict(fh=list(fh))
paronew_pred.round()
# Out:
# 2022-08    2951583.0
# 2022-09    2966611.0
# 2022-10    3023317.0
# 2022-11    3024964.0
# 2022-12    2977991.0
# Freq: M, dtype: float64

# %%
# Representamos gráficamente:
plot_series(y, paronew_pred, labels=["Paro intervenido", "Paro int PRED"])
plt.show()
