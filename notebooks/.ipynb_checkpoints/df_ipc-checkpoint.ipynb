# %% [markdown]
# # **Índice de Precios al Consumidor España**

# %% [markdown]
# ## *Librerías*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
from sktime.forecasting.arima import AutoARIMA
from statsmodels.graphics import tsaplots
from sktime.utils.plotting import plot_correlations
from statsmodels.tsa.seasonal import seasonal_decompose
from sktime.transformations.series.boxcox import LogTransformer
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.transformations.series.difference import Differencer
from sktime.utils.plotting import plot_series
from sktime.forecasting.ets import AutoETS
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Lectura del CSV y preparación de los datos*
# Se procede a leer el archivo CSV del Índice del Precio al Consumidor en España.
#
# - Fuente: https://www.ine.es/consul/serie.do?d=true&s=IPC206448&c=2&&nocab

# %%
df_ipc = pd.read_csv("ipc.csv", sep = ";")
df_ipc
# Out:
#        Variable1           Valor1       Variable2          Valor2  \
# 0   Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 1   Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 2   Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 3   Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 4   Tipo de dato  Variación anual  Total Nacional  Total Nacional
# ..           ...              ...             ...             ...
# 95  Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 96  Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 97  Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 98  Tipo de dato  Variación anual  Total Nacional  Total Nacional
# 99  Tipo de dato  Variación anual  Total Nacional  Total Nacional
#
#          Variable3          Valor3  PERIODO VALOR
# 0   Grupos ECOICOP  Índice general  2021M12   6,5
# 1   Grupos ECOICOP  Índice general  2021M11   5,5
# 2   Grupos ECOICOP  Índice general  2021M10   5,4
# 3   Grupos ECOICOP  Índice general  2021M09   4,0
# 4   Grupos ECOICOP  Índice general  2021M08   3,3
# ..             ...             ...      ...   ...
# 95  Grupos ECOICOP  Índice general  2014M01   0,2
# 96  Grupos ECOICOP  Índice general  2013M12   0,3
# 97  Grupos ECOICOP  Índice general  2013M11   0,2
# 98  Grupos ECOICOP  Índice general  2013M10  -0,1
# 99  Grupos ECOICOP  Índice general  2013M09   0,3
#
# [100 rows x 8 columns]

# %%
df_ipc = df_ipc.iloc[:,-2:]

# %%
df_ipc['PERIODO'] = df_ipc['PERIODO'].str.replace('M', '')
df_ipc['PERIODO'] = pd.to_datetime(df_ipc['PERIODO'], format='%Y%m')
df_ipc = df_ipc.set_index("PERIODO")
df_ipc
# Out:
#            VALOR
# PERIODO
# 2021-12-01   6,5
# 2021-11-01   5,5
# 2021-10-01   5,4
# 2021-09-01   4,0
# 2021-08-01   3,3
# ...          ...
# 2014-01-01   0,2
# 2013-12-01   0,3
# 2013-11-01   0,2
# 2013-10-01  -0,1
# 2013-09-01   0,3
#
# [100 rows x 1 columns]

# %%
df_ipc['VALOR']=df_ipc['VALOR'].str.replace(',', '.').astype(float)
df_ipc
# Out:
#             VALOR
# PERIODO
# 2021-12-01    6.5
# 2021-11-01    5.5
# 2021-10-01    5.4
# 2021-09-01    4.0
# 2021-08-01    3.3
# ...           ...
# 2014-01-01    0.2
# 2013-12-01    0.3
# 2013-11-01    0.2
# 2013-10-01   -0.1
# 2013-09-01    0.3
#
# [100 rows x 1 columns]

# %%
sns.set(rc={'figure.figsize':(20, 10)})
fig = df_ipc.plot(marker='.') 
fig.set_ylabel('Variación (en %)', fontsize = 30)
fig.axvline('2020-03-01', color = 'red', linewidth= 1.5)
fig.set_xlabel('Periodo', fontsize = 30);

# %% [markdown]
# # <font color = red> ANALIZAR </font>
#
# A continuación, analizaremos la estacionalidad mediante:
# - Cálculo de la media y de la varianza
# - Gráficas de comportamiento mensual
# - Desglose de la tendencia, de la estacionalidad y residuos

# %%
def split_and_summarize(dataframe, column, size, fn):
    ranges = []
    values = []
    for i in range(0, len(dataframe), size):
        ranges.append(dataframe[i:i + size])
    for i in ranges:
        values.append(fn(i[column]))
    return(values)

# %%
media = split_and_summarize(df_ipc, 'VALOR', 4, np.mean)

varianza = split_and_summarize(df_ipc, 'VALOR', 4, np.var)

# %%
cols = ['media', 'varianza']
df = pd.DataFrame([media, varianza], index=cols)

sns.set(rc={'figure.figsize':(15, 7)})
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(media, ',-')
ax1.set_ylabel('Media')

ax2.plot(varianza, ',-')
ax2.set_ylabel('Varianza')

plt.show()

# %% [markdown]
# # <font color = red> CORREGIR ESTE FALLO </font>

# %%
# Componente estacional mensual:
ax = plt.gca() 
sm.graphics.tsa.month_plot(df_ipc['VALOR'], ax = ax)
ax.set_title('Comportamiento mensual', fontsize = 30);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ALEJAN~1.RIV\AppData\Local\Temp/ipykernel_22116/4029500176.py in <module>
#       1 # Componente estacional mensual:
#       2 ax = plt.gca()
# ----> 3 sm.graphics.tsa.month_plot(df_ipc['VALOR'], ax = ax)
#       4 ax.set_title('Comportamiento mensual', fontsize = 30);
#
# ~\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in month_plot(x, dates, ylabel, ax)
#     460         from statsmodels.tools.data import _check_period_index
#     461
# --> 462         _check_period_index(x, freq="M")
#     463     else:
#     464         x = pd.Series(x, index=pd.PeriodIndex(dates, freq="M"))
#
# ~\anaconda3\lib\site-packages\statsmodels\tools\data.py in _check_period_index(x, freq)
#      16         inferred_freq = pd.infer_freq(x.index)
#      17     if not inferred_freq.startswith(freq):
# ---> 18         raise ValueError("Expected frequency {}. Got {}".format(inferred_freq,
#      19                                                                 freq))
#      20
#
# ValueError: Expected frequency -1MS. Got M

# %%
df_ipc['M'] = df_ipc.index.month
sns.boxplot(data = df_ipc, x = 'M', y='VALOR', showmeans=True)
ax = plt.gca()
ax.set_ylabel('ÍNDICE DEL PRECIO AL CONSUMIDOR', fontsize = 20)
ax.set_title('Comportamiento mensual', fontsize = 30);

# %%
desglose = seasonal_decompose(df_ipc['VALOR'], 
                                   model='additive', 
                                   period=12);
desglose.plot();
