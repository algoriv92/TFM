# %% [markdown]
# <div>
# <img src="attachment:Logo%20CUNEF.jpg" align="left" width="150"/>
# </div>

# %% [markdown]
# # **Número de vuelos de pasajeros en España**
# En este notebook se mostrará la serie temporal del **número de vuelos de pasajeros en España** y observaremos cómo afectó ésta frente al COVID-19.

# %% [markdown]
# Estructura del notebook:
#
#     1) Librerías utilizadas
#     2) Lectura y preprocesado de los datos
#     3) EDA (Análisis Exploratorio de Datos)
#     4) Elección del modelo predictivo
#         4.1) Modelo de suavizado exponencial (ETS)
#         4.2) Modelo autorregresivo integrado de media móvil (ARIMA)
#         4.3) Modelo FB Prophet
#     5) Predicción hasta finales de año

# %% [markdown]
# ## *1) Librerías utilizadas*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
from prophet import Prophet
from sktime.forecasting.arima import AutoARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics import tsaplots
from sktime.utils.plotting import plot_correlations
from statsmodels.tsa.seasonal import seasonal_decompose
from sktime.transformations.series.boxcox import LogTransformer
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sktime.performance_metrics.forecasting import MeanSquaredError
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.transformations.series.difference import Differencer
from sktime.utils.plotting import plot_series
from sktime.forecasting.ets import AutoETS
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *2) Lectura del csv y preprocesado de los datos*
#
# Se procede a la lectura del CSV del tráfico aéreo en España, ofrecidos por AENA.
# - Fuente: https://www.aena.es/es/estadisticas/inicio.html

# %%
df_vuelos = pd.read_excel("vuelos.xlsx")
df_vuelos = df_vuelos.set_index("Periodo")
df_vuelos
# Out:
#             Total Pasajeros  Total Mercancías
# Periodo
# 2014-01-01         10959721          51279738
# 2014-02-01         10779086          51395821
# 2014-03-01         13446155          60074235
# 2014-04-01         16246439          55234845
# 2014-05-01         17540838          56289587
# ...                     ...               ...
# 2022-02-01         11908046          78764432
# 2022-03-01         15587273          92308548
# 2022-04-01         20458260          82681716
# 2022-05-01         22262317          83021678
# 2022-06-01         24320204          80067687
#
# [102 rows x 2 columns]

# %% [markdown]
# Para este caso, estudiaremos únicamente el tráfico aéreo para las mercancías.

# %%
df_vuelos=df_vuelos.drop('Total Mercancías', axis=1)
df_vuelos
# Out:
#             Total Pasajeros
# Periodo
# 2014-01-01         10959721
# 2014-02-01         10779086
# 2014-03-01         13446155
# 2014-04-01         16246439
# 2014-05-01         17540838
# ...                     ...
# 2022-02-01         11908046
# 2022-03-01         15587273
# 2022-04-01         20458260
# 2022-05-01         22262317
# 2022-06-01         24320204
#
# [102 rows x 1 columns]

# %% [markdown]
# Chequeamos posibles valores faltantes en 'Total Pasajeros', en el caso de que los haya los rellenaríamos aplicando una media o bien aplicando el dato del mes anterior.

# %%
df_vuelos.isnull().sum()
# Out:
# Total Pasajeros    0
# dtype: int64

# %% [markdown]
# No hay errores en los periodos observados, por lo que vamos a proceder a la realización del análisis exploratorio mediante gráficos y cálculos estadísticos. Pero antes vamos a realizar un rename de las columnas con el formato necesario para algunos modelos como el Prophet:

# %% [markdown]
# ## *3) EDA*

# %%
# Ploteamos nuestra serie temporal:
sns.set(rc={'figure.figsize':(16,8)})
fig = df_vuelos.plot(marker='.') 
fig.set_ylabel('Nº vuelos (mill)', fontsize = 30)
fig.axvline('2020-03-01', color = 'red', linewidth= 1.5)
fig.set_xlabel('Meses', fontsize = 30);
# fig.figure.savefig('../pics/df_vuelos_pasajeros/tendencia.png')

# %% [markdown]
# Como pasaba con los vuelos de turistas, **existía una tendencia creciente hasta la época COVID**, en la que se redujeron el número de vuelos de mercancías, en cambio parece estar recuperando los números. También podemos apreciar que tiene una **fuerte estacionalidad** porque donde más vuelos de pasajeros hay es en la época de verano.

# %% [markdown]
# A continuación, analizaremos la estacionalidad y comprobaremos si la serie temporal es estacionaria mediante:
# - Cálculo de la media y de la varianza
# - Test de Dickey-Fuller aumentada
# - Gráficas de comportamiento mensual
# - Descomposición

# %% [markdown]
# ### 3.1) Cálculo de la media y de la varianza

# %%
def split_and_summarize(dataframe, column, size, fn):
    ranges = []
    values = []
    for i in range(0, len(dataframe), size):
        ranges.append(dataframe[i:i + size])
    for i in ranges:
        values.append(fn(i[column]))
    return(values)

media=split_and_summarize(df_vuelos,'Total Pasajeros',4,np.mean)
varianza=split_and_summarize(df_vuelos,'Total Pasajeros',4,np.var)

# %%
cols=['media','varianza']
df=pd.DataFrame([media,varianza], index=cols)

sns.set(rc={'figure.figsize':(15, 7)})
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(media, ',-')
ax1.set_ylabel('Media')

ax2.plot(varianza, ',-')
ax2.set_ylabel('Varianza')

plt.show()
# fig.figure.savefig('../pics/df_vuelos_pasajeros/meanvariance.png')

# %% [markdown]
# A simple vista no parece una serie temporal estacionaria en cuanto a su media, pero la varianza, a pesar del pico del momento COVID-19, no queda muy claro si es estacionaria o no, por lo que procedemos a realizar la prueba de Dickey-Fuller aumentado.

# %% [markdown]
# ### 3.2) Test de Dickey-Fuller aumentado
#
# Esta prueba nos proporciona una verificación rápida y evidente de si la serie es estacionaria o no.
#
# **La hipótesis nula (H0)** de la prueba es que la serie temporal se puede representar mediante una raíz unitaria, que no es estacionaria, es decir, que tiene alguna estructura dependiente del tiempo.
#
# **La hipótesis alternativa (H1)**, que rechaza la hipótesis nula, indica que la serie temporal es estacionaria.
#
# Interpretamos este resultado utilizando el p-value. Un valor p por debajo del umbral de significancia (0.05) significa que la hipótesis nula se rechaza.

# %%
def test_stationarity(timeseries):
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

test_stationarity(df_vuelos)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.841692
# p-value                          0.052561
# #Lags Used                       0.000000
# Number of Observations Used    101.000000
# Critical Value (1%)             -3.496818
# Critical Value (5%)             -2.890611
# Critical Value (10%)            -2.582277
# dtype: float64

# %% [markdown]
# Confirmamos que **NO es una serie estacionaria** ya que su p-value es mayor que 0.05, lo que significa que habrá que realizar cambios en sus datos para los modelos.

# %% [markdown]
# ### 3.3) Gráficas de comportamiento mensual
#
# A continuación vamos a analizar con más detalle la estacionalidad y su tendencia:

# %%
ax = plt.gca() 
sm.graphics.tsa.month_plot(df_vuelos['Total Pasajeros'], ax = ax)
ax.set_title('Comportamiento mensual mercancías', fontsize = 30);
# ax.figure.savefig('../pics/df_vuelos_pasajeros/monthbehavior.png')

# %% [markdown]
# Pasamos a realizar un boxplot mensual para estudiar las distribuciones:

# %%
df_vuelos['M'] = df_vuelos.index.month
sns.boxplot(data = df_vuelos, x = 'M', y='Total Pasajeros', showmeans=True)
ax = plt.gca()
ax.set_ylabel('Nº vuelos pasajeros', fontsize = 20)
ax.set_title('Comportamiento mensual mercancías', fontsize = 30);
# ax.figure.savefig('../pics/df_vuelos_pasajeros/boxplotmonth.png')

# %% [markdown]
# Como habíamos dicho antes, hay una clara estacionalidad donde predominan más vuelos en los meses correspondientes al verano.

# %% [markdown]
# ### 3.4) Descomposición
#
# Y, por último, el desglose de la estacionalidad, tendencia y residuos:

# %%
desglose_mercancias = seasonal_decompose(df_vuelos['Total Pasajeros'], 
                                   model='additive', 
                                   period=12);
desglose_mercancias.plot();
# plt.savefig('../pics/df_vuelos_pasajeros/decompose.png')

# %% [markdown]
# Como resumen del EDA:
# - Tenía tendencia creciente hasta el inicio de la pandemia, decrece y a finales del mismo año recupera su tendencia creciente.
# - No es una serie estacionaria.
# - Tiene estacionalidad.

# %% [markdown]
# ## *4) Estimación mediante modelos*
#
# ### 4.1) Modelo de Suavizado Exponencial (ETS)
#
# A continuación, se realiza una segmentación en la estimación y en la parte de predicción (Training-Testing), prediciéndolo en el tiempo que ha habido desde el inicio de la pandemia, es decir, desde marzo del 2020. Como el dataset tiene datos hasta julio del 2022, hay 29 meses para el test_size.

# %%
#Train-test
y_train, y_test = temporal_train_test_split(
    y=df_vuelos['Total Pasajeros'].astype('float64').to_period('M'),test_size=29)
#Grafico para representar la separación de los datos
plot_series(y_train, y_test, labels=["y_train", "y_test"])
print('Cantidad de períodos en Train:', y_train.shape[0])
print('Cantidad de períodos en Test:', y_test.shape[0]);
# Out:
# Cantidad de períodos en Train: 73
# Cantidad de períodos en Test: 29

# %%
y_test #observamos los 29 meses testeados
# Out:
# 2020-02    33886751.0
# 2020-03     8128859.0
# 2020-04      141014.0
# 2020-05      267671.0
# 2020-06     1053780.0
# 2020-07     6987828.0
# 2020-08     8951753.0
# 2020-09     5457083.0
# 2020-10     4458349.0
# 2020-11     2913072.0
# 2020-12     3818162.0
# 2021-01     2814424.0
# 2021-02     2229568.0
# 2021-03     3200222.0
# 2021-04     3671802.0
# 2021-05     5889921.0
# 2021-06     9266794.0
# 2021-07    15138997.0
# 2021-08    18011330.0
# 2021-09    16316040.0
# 2021-10    17256634.0
# 2021-11    13442676.0
# 2021-12    12721263.0
# 2022-01    10403137.0
# 2022-02    11908046.0
# 2022-03    15587273.0
# 2022-04    20458260.0
# 2022-05    22262317.0
# 2022-06    24320204.0
# Freq: M, Name: Total Pasajeros, dtype: float64

# %% [markdown]
# Se realiza el pronóstico (forecasting) del horizonte temporal de 2 años. En sp, que es el número de periodos en un ciclo estacional completo, pondremos 12 para datos mensuales con ciclo anual:

# %%
# Especifico la cantidad de períodos a estimar para obtener las observaciones predichas en test.
fh = np.arange(1, y_test.shape[0]+1)

# Selecciono el modelo y sus parámetros de predicción, al igual que los recursos a utilizar para entrenar
vuelos_auto_ets = AutoETS(auto=True, sp=12, n_jobs=-1)

# %%
vuelos_auto_ets.fit(y_train)
vuelos_auto_ets.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  ETS Results
# ==============================================================================
# Dep. Variable:        Total Pasajeros   No. Observations:                   73
# Model:                       ETS(MNM)   Log Likelihood               -1098.491
# Date:                Tue, 30 Aug 2022   AIC                           2228.982
# Time:                        17:51:44   BIC                           2265.629
# Sample:                    01-31-2014   HQIC                          2243.586
#                          - 01-31-2020   Scale                            0.002
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999        nan        nan        nan         nan         nan
# smoothing_seasonal   9.841e-05        nan        nan        nan         nan         nan
# initial_level        1.624e+07        nan        nan        nan         nan         nan
# initial_seasonal.0      1.0632        nan        nan        nan         nan         nan
# initial_seasonal.1      1.0870        nan        nan        nan         nan         nan
# initial_seasonal.2      1.5142        nan        nan        nan         nan         nan
# initial_seasonal.3      1.6724        nan        nan        nan         nan         nan
# initial_seasonal.4      1.8666        nan        nan        nan         nan         nan
# initial_seasonal.5      1.8523        nan        nan        nan         nan         nan
# initial_seasonal.6      1.6616        nan        nan        nan         nan         nan
# initial_seasonal.7      1.5340        nan        nan        nan         nan         nan
# initial_seasonal.8      1.4077        nan        nan        nan         nan         nan
# initial_seasonal.9      1.2153        nan        nan        nan         nan         nan
# initial_seasonal.10     0.9855        nan        nan        nan         nan         nan
# initial_seasonal.11     1.0000        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (Q):                        3.08   Jarque-Bera (JB):              5399.16
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            -5.71
# Prob(H) (two-sided):                  0.00   Kurtosis:                        43.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 1.16e+19. Standard errors may be unstable.
# """

# %%
#step 5: querying predictions
vuelos_pred = vuelos_auto_ets.predict(fh=list(fh))
vuelos_pred.round()
# Out:
# 2020-02    16736998.0
# 2020-03    20639198.0
# 2020-04    23906302.0
# 2020-05    26052523.0
# 2020-06    28218579.0
# 2020-07    31458307.0
# 2020-08    31700411.0
# 2020-09    28401484.0
# 2020-10    25715713.0
# 2020-11    18460124.0
# 2020-12    18055937.0
# 2021-01    16982161.0
# 2021-02    16736998.0
# 2021-03    20639198.0
# 2021-04    23906302.0
# 2021-05    26052523.0
# 2021-06    28218579.0
# 2021-07    31458307.0
# 2021-08    31700411.0
# 2021-09    28401484.0
# 2021-10    25715713.0
# 2021-11    18460124.0
# 2021-12    18055937.0
# 2022-01    16982161.0
# 2022-02    16736998.0
# 2022-03    20639198.0
# 2022-04    23906302.0
# 2022-05    26052523.0
# 2022-06    28218579.0
# Freq: M, dtype: float64

# %%
# optional: plotting predictions and past data
plot_series(y_train, vuelos_pred, y_test,labels=[
    "Vuelos pasajeros", "Vuelos pasajeros PRED", "Vuelos pasajeros REAL"]);

# %% [markdown]
# Se hace un zoom al gráfico:

# %%
plot_series(y_train["2019":], vuelos_pred,y_test, labels=[
    "Vuelos pasajeros", "Vuelos pasajeros PRED", "Vuelos pasajeros REAL"]);

# %% [markdown]
# La predicción por ETS, a simple vista, no predice en absoluto el momento COVID, pero a partir de después del verano del 2021 sí que afina más su precisión. Vamos a calcular el error de las predicciones mediante el RMSE y MAPE.

# %%
mse = MeanSquaredError(square_root=True)
mse_ets = mse(y_test, vuelos_pred)
print('El modelo ETS genera un RMSE de:', round(mse_ets,2))
# Out:
# El modelo ETS genera un RMSE de: 16301286.94

# %%
mape = MeanAbsolutePercentageError(symmetric=False)
mape_ets = mape(y_test, vuelos_pred)
print('El modelo ETS genera un MAPE de: {}%'.format(round(mape_ets,2)))
# Out:
# El modelo ETS genera un MAPE de: 12.08%

# %% [markdown]
# ### 4.2) Modelo ARIMA

# %% [markdown]
# Al tratarse de una serie no estacionaria en media ni en varianza, debemos transformar a la serie para tener un correcto tratamiento de la misma y de esta manera, obtener las mejores predicciones posibles con el método de estimacion ARIMA.
#
# Es necesario lograr que la serie sea estacionaria en varianza, luego el algoritmo es capaz de interpretar datos no estacionarios en media. Para ello, aplicaremos logaritmo y luego lo ploteamos para evidenciar si se ha logrado el objetivo.

# %%
transformer = LogTransformer()
log_df_vuelos= transformer.fit_transform(df_vuelos['Total Pasajeros'])
log_df_vuelos.tail()
# Out:
# Periodo
# 2022-02-01    16.292725
# 2022-03-01    16.561965
# 2022-04-01    16.833897
# 2022-05-01    16.918406
# 2022-06-01    17.006818
# dtype: float64

# %%
sns.set(rc={'figure.figsize':(20, 10)})
fig = log_df_vuelos.plot(marker='.', color = 'black', linewidth= 2) 
fig.set_title('Vuelos pasajeros en España', fontsize = 30) 
fig.set_ylabel('LOG Vuelos', fontsize = 30)
fig.set_xlabel('Periodo', fontsize = 30);

# %% [markdown]
# Separamos el train y test a la serie transformada en logs:

# %%
y_log_train,y_log_test=temporal_train_test_split(
    y=log_df_vuelos.astype('float64').to_period('M').sort_index(),test_size=29)
plot_series(y_log_train, y_log_test, labels=["y_log_train", "y_log_test"])
y_log_train.shape[0], y_log_test.shape[0];

# %% [markdown]
# Generamos el modelo y se entrena con los datos del train:

# %%
fh = np.arange(1,y_log_test.shape[0]+1)
vuelos_auto_arima=AutoARIMA(sp=12,suppress_warnings=True)

# %%
vuelos_auto_arima.fit(y_log_train)
vuelos_auto_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   73
# Model:             SARIMAX(1, 1, 1)x(2, 0, [], 12)   Log Likelihood                 144.448
# Date:                             Tue, 30 Aug 2022   AIC                           -278.896
# Time:                                     17:53:29   BIC                           -267.513
# Sample:                                          0   HQIC                          -274.365
#                                               - 73
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6222      0.151      4.117      0.000       0.326       0.918
# ma.L1         -0.9109      0.084    -10.869      0.000      -1.075      -0.747
# ar.S.L12       0.5773      0.093      6.215      0.000       0.395       0.759
# ar.S.L24       0.4135      0.093      4.428      0.000       0.230       0.597
# sigma2         0.0006   9.81e-05      5.686      0.000       0.000       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.57   Jarque-Bera (JB):                 2.75
# Prob(Q):                              0.45   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.53   Skew:                             0.21
# Prob(H) (two-sided):                  0.13   Kurtosis:                         3.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
vuelos_log_pred = vuelos_auto_arima.predict(fh)
np.exp(vuelos_log_pred.round())
# Out:
# 2020-02    2.415495e+07
# 2020-03    2.415495e+07
# 2020-04    2.415495e+07
# 2020-05    2.415495e+07
# 2020-06    2.415495e+07
# 2020-07    2.415495e+07
# 2020-08    2.415495e+07
# 2020-09    2.415495e+07
# 2020-10    2.415495e+07
# 2020-11    2.415495e+07
# 2020-12    2.415495e+07
# 2021-01    2.415495e+07
# 2021-02    2.415495e+07
# 2021-03    2.415495e+07
# 2021-04    2.415495e+07
# 2021-05    2.415495e+07
# 2021-06    2.415495e+07
# 2021-07    2.415495e+07
# 2021-08    2.415495e+07
# 2021-09    2.415495e+07
# 2021-10    2.415495e+07
# 2021-11    2.415495e+07
# 2021-12    2.415495e+07
# 2022-01    2.415495e+07
# 2022-02    2.415495e+07
# 2022-03    2.415495e+07
# 2022-04    2.415495e+07
# 2022-05    2.415495e+07
# 2022-06    2.415495e+07
# Freq: M, dtype: float64

# %%
# representamos la serie predictiva
plot_series(np.exp(y_log_train), np.exp(vuelos_log_pred), np.exp(y_log_test), 
            labels=["Vuelos pasajeros", "Vuelos pasajeros PRED", "Vuelos pasajeros REAL"]);

# %%
mse = MeanSquaredError(square_root=True)
mse_log = mse(np.exp(y_log_test), np.exp(vuelos_log_pred))
print('El modelo ARIMA genera un RMSE de:', round(mse_log,2))
# Out:
# El modelo ARIMA genera un RMSE de: 17029571.58

# %%
mape = MeanAbsolutePercentageError()
mape_log = mape(y_log_test, vuelos_log_pred)
print('El modelo ARIMA genera un MAPE de: {}%'.format(round(mape_log*100,2)))
# Out:
# El modelo ARIMA genera un MAPE de: 8.82%

# %% [markdown]
# #### Una comparativa entre ETS y ARIMA

# %%
plot_series(np.exp(y_log_train["2019":]), np.exp(vuelos_log_pred), np.exp(y_log_test), vuelos_pred, 
            labels=["Vuelos pasajeros", 
                    "Vuelos pasajeros ARIMA", 
                    "Vuelos pasajeros REAL", "Vuelos pasajeros ETS"]);
# plt.savefig(../pics/df_vuelos_pasajeros/etsarima.png)

# %% [markdown]
# Ahora comparamos entre las métricas de error que tenemos:
# 1) RMSE (Error dependiente de la escala)

# %%
print('El modelo ETS genera un RMSE de:', round(mse_ets,2))
print('El modelo ARIMA genera un RMSE de:', round(mse_log,2))
# Out:
# El modelo ETS genera un RMSE de: 16301286.94
# El modelo ARIMA genera un RMSE de: 17029571.58

# %%
print('El modelo ETS genera un MAPE de: {}%'.format(round(mape_ets,2)))
print('El modelo ARIMA genera un MAPE de {}%'.format(round(mape_log*100,2)))
# Out:
# El modelo ETS genera un MAPE de: 12.08%
# El modelo ARIMA genera un MAPE de 8.82%

# %% [markdown]
# Confirmamos que el modelo ARIMA, para este caso concreto, predice algo mejor ya que su error es menor.

# %% [markdown]
# ### 4.3) Prophet

# %% [markdown]
# FB Prophet es un modelo muy extendido para la predicción de series temporales desarrollado por Facebook. El objetivo de este paquete es dar a los usuarios una herramienta potente y de fácil uso para predecir resultados de distintas series temporales. Este modelo alcanza sus mejores resultados con series estacionarias o series con una tendencia y estacionalidad marcadas, como es el caso del turismo en España. Suele ser peor cuando aumenta la aleatoria de la muestra.

# %% [markdown]
# Dentro de nuestro DataFrame cambiamos el nombre de la columna temporal *'Periodo'* y la de la variable objetivo *'Total'* por *'ds'* e *'y'*, y también quitamos el Periodo como índice, pues todos estos cambios son necesarios para que el modelo funcione bien.

# %%
df_vuelos_prophet=pd.read_excel("vuelos.xlsx")
df_vuelos_prophet=df_vuelos_prophet.drop('Total Mercancías',axis=1)
df_vuelos_prophet
# Out:
#        Periodo  Total Pasajeros
# 0   2014-01-01         10959721
# 1   2014-02-01         10779086
# 2   2014-03-01         13446155
# 3   2014-04-01         16246439
# 4   2014-05-01         17540838
# ..         ...              ...
# 97  2022-02-01         11908046
# 98  2022-03-01         15587273
# 99  2022-04-01         20458260
# 100 2022-05-01         22262317
# 101 2022-06-01         24320204
#
# [102 rows x 2 columns]

# %%
prophet_train = df_vuelos_prophet #cambiamos de índice
prophet_train.columns = ['ds', 'y'] #renombramos las columnas

# %%
prophet_y_train = y_train.copy()
prophet_y_train = prophet_y_train.rename_axis('index').reset_index()
prophet_y_train.columns = ['ds', 'y']
prophet_y_train['ds'] = prophet_y_train['ds'].dt.to_timestamp(freq = 'M')
len(prophet_y_train)
# Out:
# 73

# %%
prophet_y_test = y_test.copy()
prophet_y_test = prophet_y_test.rename_axis('index').reset_index()
prophet_y_test.columns = ['ds', 'y']
prophet_y_test['ds'] = prophet_y_test['ds'].dt.to_timestamp(freq = 'M')
len(prophet_y_test)
# Out:
# 29

# %%
prophet_y_train.tail()
# Out:
#            ds           y
# 68 2019-09-30  27137706.0
# 69 2019-10-31  24699768.0
# 70 2019-11-30  18349196.0
# 71 2019-12-31  18248209.0
# 72 2020-01-31  16982161.0

# %%
prophet_y_test.head()
# Out:
#           ds           y
# 0 2020-02-29  33886751.0
# 1 2020-03-31   8128859.0
# 2 2020-04-30    141014.0
# 3 2020-05-31    267671.0
# 4 2020-06-30   1053780.0

# %%
m = Prophet()
m.fit(prophet_y_train)
# Out:
# 17:56:19 - cmdstanpy - INFO - Chain [1] start processing
# 17:56:19 - cmdstanpy - INFO - Chain [1] done processing

# %%
m_pred = m.make_future_dataframe(periods=len(prophet_y_test), freq='M')
prophet_forecast = m.predict(m_pred)

# %%
plt.plot(list(prophet_y_test['y']), '.-')
plt.plot(list(prophet_forecast.loc[73:, 'yhat']), '.-', label='Predicition')
plt.show()
# plt.savefig(../pics/df_vuelos_pasajeros/prophet.png)

# %%
# Forecast Accuracy
# MAPE
# mape_prophet = mean_absolute_percentage_error(prophet_y_test['y'], prophet_forecast.loc[47:, 'yhat'])
# mape_prophet

mape = MeanAbsolutePercentageError(symmetric=False)
mape_prophet = mape(prophet_y_test['y'], prophet_forecast.loc[73:, 'yhat'])
print('El modelo Prophet genera un MAPE de: {}%'.format(round(mape_prophet,2)))
# Out:
# El modelo Prophet genera un MAPE de: 11.89%

# %%
# Forecast Accuracy
#Mean Squared Error
mse = MeanSquaredError(square_root=True)
mse_prophet = mse(prophet_y_test['y'],prophet_forecast.loc[73:, 'yhat'])
print('El modelo Prophet genera un RMSE de:', round(mse_prophet,2))
# Out:
# El modelo Prophet genera un RMSE de: 16279023.26

# %%
prophet_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].round().tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 97  2022-02-28  19144987.0  18523727.0  19766662.0
# 98  2022-03-31  22364728.0  21705146.0  23016112.0
# 99  2022-04-30  25094315.0  24417491.0  25779048.0
# 100 2022-05-31  26846365.0  26198300.0  27548703.0
# 101 2022-06-30  28763183.0  28016098.0  29436840.0

# %% [markdown]
# ### 4.4) Comparativa errores y elección del mejor modelo

# %% [markdown]
# Ahora comparamos entre las métricas de error que tenemos:
# 1) RMSE (Error dependiente de la escala)

# %%
print('El modelo ETS genera un RMSE de:', round(mse_ets,2))
print('El modelo ARIMA genera un RMSE de:', round(mse_log,2))
print('El modelo Prophet genera un RMSE de:', round(mse_prophet,2))
# Out:
# El modelo ETS genera un RMSE de: 16301286.94
# El modelo ARIMA genera un RMSE de: 17029571.58
# El modelo Prophet genera un RMSE de: 16279023.26

# %% [markdown]
# 2) MAPE (Error porcentual)

# %%
print('El modelo ETS genera un MAPE de: {}%'.format(round(mape_ets,2)))
print('El modelo ARIMA genera un MAPE de {}%'.format(round(mape_log*100,2)))
print('El modelo Prophet genera un MAPE de {}%'.format(round(mape_prophet,2)))
# Out:
# El modelo ETS genera un MAPE de: 12.08%
# El modelo ARIMA genera un MAPE de 8.82%
# El modelo Prophet genera un MAPE de 11.89%

# %% [markdown]
# Confirmamos que **el mejor modelo para la predicción de esta serie temporal es la ARIMA**, ya que es el que mejor se ajusta a los datos reales y es el que menor error da, aunque se considera que es un error un poco elevado.

# %% [markdown]
# ## *5) Predicción hasta finales de año*

# %% [markdown]
# A continuación realizamos la predicción de la serie temporal del número de vuelos de pasajeros hasta finales de año, es decir, hasta diciembre del 2022.

# %%
fh = np.arange(1,7)
autoarima_predict = AutoARIMA(sp=12,suppress_warnings=True)
y = transformer.fit_transform(df_vuelos['Total Pasajeros'].astype('float64').to_period('M').sort_index())
autoarima_predict.fit(y)
# Out:
# AutoARIMA(sp=12, suppress_warnings=True)

# %%
# Modelo AutoARIMA:

print(autoarima_predict.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  102
# Model:               SARIMAX(3, 0, 0)   Log Likelihood                 -63.868
# Date:                Mon, 29 Aug 2022   AIC                            137.736
# Time:                        19:43:45   BIC                            150.861
# Sample:                             0   HQIC                           143.051
#                                 - 102
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      3.3835      0.858      3.941      0.000       1.701       5.066
# ar.L1          1.2085      0.045     27.065      0.000       1.121       1.296
# ar.L2         -0.6317      0.091     -6.922      0.000      -0.811      -0.453
# ar.L3          0.2176      0.075      2.894      0.004       0.070       0.365
# sigma2         0.2018      0.017     11.952      0.000       0.169       0.235
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              4825.24
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.88   Skew:                            -4.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                        35.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
vuelosnew_pred = autoarima_predict.predict(fh=list(fh))
vuelosnew_pred
# Out:
# 2022-07    16.912998
# 2022-08    16.762157
# 2022-09    16.658365
# 2022-10    16.607796
# 2022-11    16.579419
# 2022-12    16.554482
# Freq: M, dtype: float64

# %%
np.exp(vuelosnew_pred) # a número
# Out:
# 2022-07    2.214224e+07
# 2022-08    1.904199e+07
# 2022-09    1.716470e+07
# 2022-10    1.631827e+07
# 2022-11    1.586171e+07
# 2022-12    1.547106e+07
# Freq: M, dtype: float64

# %%
# Representamos gráficamente:
plot_series(np.exp(y_log_train),np.exp(vuelosnew_pred),labels=["Vuelos Pasajeros","Vuelos Pasajeros pred"])
# plt.savefig('../pics/df_vuelos_pasajeros/predict2022.png')
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:>)
