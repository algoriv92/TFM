# %%
import pandas as pd

# %%
pd.read_csv("be2501.csv", sep = ",", encoding='latin-1')
# Out:
#               NOMBRE DE LA SERIE  \
# 0              NÚMERO SECUENCIAL
# 1              ALIAS DE LA SERIE
# 2        DESCRIPCIÓN DE LA SERIE
# 3    DESCRIPCIÓN DE LAS UNIDADES
# 4                     FRECUENCIA
# ..                           ...
# 248                     ABR 2022
# 249                     MAY 2022
# 250                     JUN 2022
# 251                       FUENTE
# 252                        NOTAS
#
#                                      DIP2021LINP_E00.M  \
# 0                                              4144805
# 1                                            BE_25_1.1
# 2    Índice de Precios de Consumo (IPC). Año Base 2...
# 3                                        Base_2016=100
# 4                                              MENSUAL
# ..                                                 ...
# 248                                            107.375
# 249                                            108.262
# 250                                            110.267
# ...
